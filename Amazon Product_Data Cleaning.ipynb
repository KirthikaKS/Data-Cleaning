# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\KIRTHIKA K S\\Downloads\\amazon_product.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0        asin                                      product_title  \
# 0           0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1           1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2           2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3           3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4           4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
#
#   product_price product_original_price currency  product_star_rating  \
# 0        $99.99                $169.99      USD                  4.0
# 1       $149.74                $158.00      USD                  4.2
# 2        $49.88                    NaN      USD                  3.9
# 3       $335.00                $499.00      USD                  4.3
# 4       $199.99                    NaN      USD                  4.1
#
#    product_num_ratings                           product_url  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'asin', 'product_title', 'product_price',
#        'product_original_price', 'currency', 'product_star_rating',
#        'product_num_ratings', 'product_url', 'product_photo',
#        'product_num_offers', 'product_minimum_offer_price', 'is_best_seller',
#        'is_amazon_choice', 'is_prime', 'climate_pledge_friendly',
#        'sales_volume', 'delivery', 'has_variations', 'product_availability',
#        'unit_price', 'unit_count'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0                      0
# asin                            0
# product_title                   0
# product_price                   0
# product_original_price         37
# currency                        0
# product_star_rating            10
# product_num_ratings             0
# product_url                     0
# product_photo                   0
# product_num_offers              0
# product_minimum_offer_price     0
# is_best_seller                  0
# is_amazon_choice                0
# is_prime                        0
# climate_pledge_friendly         0
# sales_volume                    3
# delivery                        1
# has_variations                  0
# product_availability           63
# unit_price                     59
# unit_count                     59
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#DELETE REDUNDANT COLUMNS
df.drop(columns = "Unnamed: 0", inplace = True)

# %%
df
# Out:
#           asin                                      product_title  \
# 0   B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1   B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2   B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3   B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4   B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
# ..         ...                                                ...
# 59  B0D6LWXK1R  Greatish Hits: I Followed My Dreams and My Dre...
# 60  B0CLKQF5HR                                          Swan Song
# 61  B0BZFHK12K                            Bluey: Let&#x27;s Play!
# 62  B09Z7J4L6X  Xbox Wireless Controller – Sky Cipher Special ...
# 63  B0CT2R7199  HP DeskJet 2855e Wireless All-in-One Color Ink...
#
#    product_price product_original_price currency  product_star_rating  \
# 0         $99.99                $169.99      USD                  4.0
# ...

# %%
df.columns
# Out:
# Index(['asin', 'product_title', 'product_price', 'product_original_price',
#        'currency', 'product_star_rating', 'product_num_ratings', 'product_url',
#        'product_photo', 'product_num_offers', 'product_minimum_offer_price',
#        'is_best_seller', 'is_amazon_choice', 'is_prime',
#        'climate_pledge_friendly', 'sales_volume', 'delivery', 'has_variations',
#        'product_availability', 'unit_price', 'unit_count'],
#       dtype='object')

# %%
df.drop(columns = ['asin', 'product_url','product_photo', 'product_num_offers', 'product_minimum_offer_price', 'is_amazon_choice', 'is_prime',
       'climate_pledge_friendly', 'sales_volume', 'delivery', 'has_variations' ], inplace = True)

# %%
df.columns
# Out:
# Index(['product_title', 'product_price', 'product_original_price', 'currency',
#        'product_star_rating', 'product_num_ratings', 'is_best_seller',
#        'product_availability', 'unit_price', 'unit_count'],
#       dtype='object')

# %%
#RENAMING THE COLUMNS
df_new_column_names = []

for i in df.columns:
    df_new_column_names.append(i.capitalize())

# %%
df_new_column_names
# Out:
# ['Product_title',
#  'Product_price',
#  'Product_original_price',
#  'Currency',
#  'Product_star_rating',
#  'Product_num_ratings',
#  'Is_best_seller',
#  'Product_availability',
#  'Unit_price',
#  'Unit_count']

# %%
df.columns = df_new_column_names

# %%
df
# Out:
#                                         Product_title Product_price  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        $99.99
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       $149.74
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        $49.88
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       $335.00
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       $199.99
# ..                                                ...           ...
# 59  Greatish Hits: I Followed My Dreams and My Dre...        $34.98
# 60                                          Swan Song        $14.99
# 61                            Bluey: Let&#x27;s Play!         $0.00
# 62  Xbox Wireless Controller – Sky Cipher Special ...        $69.99
# 63  HP DeskJet 2855e Wireless All-in-One Color Ink...        $59.99
#
#    Product_original_price Currency  Product_star_rating  Product_num_ratings  \
# ...

# %%
#DROPPING DUPLICAES
df.duplicated().sum()
# Out:
# 0

# %%
df.isna()
# Out:
#     Product_title  Product_price  Product_original_price  Currency  \
# 0           False          False                   False     False
# 1           False          False                   False     False
# 2           False          False                    True     False
# 3           False          False                   False     False
# 4           False          False                    True     False
# ..            ...            ...                     ...       ...
# 59          False          False                    True     False
# 60          False          False                   False     False
# 61          False          False                    True     False
# 62          False          False                    True     False
# 63          False          False                   False     False
#
#     Product_star_rating  Product_num_ratings  Is_best_seller  \
# 0                 False                False           False
# ...

# %%
df.isna().sum()
# Out:
# Product_title              0
# Product_price              0
# Product_original_price    37
# Currency                   0
# Product_star_rating       10
# Product_num_ratings        0
# Is_best_seller             0
# Product_availability      63
# Unit_price                59
# Unit_count                59
# dtype: int64

# %%
df.shape
# Out:
# (64, 10)

# %%
df.columns
# Out:
# Index(['Product_title', 'Product_price', 'Product_original_price', 'Currency',
#        'Product_star_rating', 'Product_num_ratings', 'Is_best_seller',
#        'Product_availability', 'Unit_price', 'Unit_count'],
#       dtype='object')

# %%
#dropping the columns with most na values
df = df[['Product_title', 'Product_price','Currency','Product_star_rating', 'Product_num_ratings', 'Is_best_seller']]

# %%
df.head(1)
# Out:
#                                        Product_title Product_price Currency  \
# 0  Moto G Play 2023 3-Day Battery Unlocked Made f...        $99.99      USD
#
#    Product_star_rating  Product_num_ratings  Is_best_seller
# 0                  4.0                 2929           False

# %%
df.isna().sum()
# Out:
# Product_title           0
# Product_price           0
# Currency                0
# Product_star_rating    10
# Product_num_ratings     0
# Is_best_seller          0
# dtype: int64

# %%
df["Is_best_seller"] = df["Is_best_seller"].apply(lambda x : 1 if x == True else 0)
# Out:
# C:\Users\KIRTHIKA K S\AppData\Local\Temp\ipykernel_18552\3892662101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Is_best_seller"] = df["Is_best_seller"].apply(lambda x : 1 if x == True else 0)

# %%
df
# Out:
#                                         Product_title Product_price Currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...        $99.99      USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...       $149.74      USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...        $49.88      USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...       $335.00      USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...       $199.99      USD
# ..                                                ...           ...      ...
# 59  Greatish Hits: I Followed My Dreams and My Dre...        $34.98      USD
# 60                                          Swan Song        $14.99      USD
# 61                            Bluey: Let&#x27;s Play!         $0.00      USD
# 62  Xbox Wireless Controller – Sky Cipher Special ...        $69.99      USD
# 63  HP DeskJet 2855e Wireless All-in-One Color Ink...        $59.99      USD
#
# ...

# %%
df['Product_price'] = df['Product_price'].str.replace("$","")
# Out:
# C:\Users\KIRTHIKA K S\AppData\Local\Temp\ipykernel_18552\1695615396.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Product_price'] = df['Product_price'].str.replace("$","")
# C:\Users\KIRTHIKA K S\AppData\Local\Temp\ipykernel_18552\1695615396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Product_price'] = df['Product_price'].str.replace("$","")

# %%
df
# Out:
#                                         Product_title Product_price Currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...         99.99      USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...        149.74      USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...         49.88      USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...        335.00      USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...        199.99      USD
# ..                                                ...           ...      ...
# 59  Greatish Hits: I Followed My Dreams and My Dre...         34.98      USD
# 60                                          Swan Song         14.99      USD
# 61                            Bluey: Let&#x27;s Play!          0.00      USD
# 62  Xbox Wireless Controller – Sky Cipher Special ...         69.99      USD
# 63  HP DeskJet 2855e Wireless All-in-One Color Ink...         59.99      USD
#
# ...

# %%
df['Product_price'] = df['Product_price'].astype(float)
# Out:
# C:\Users\KIRTHIKA K S\AppData\Local\Temp\ipykernel_18552\540533000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Product_price'] = df['Product_price'].astype(float)

# %%
df
# Out:
#                                         Product_title  Product_price Currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...          99.99      USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...         149.74      USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...          49.88      USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...         335.00      USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...         199.99      USD
# ..                                                ...            ...      ...
# 59  Greatish Hits: I Followed My Dreams and My Dre...          34.98      USD
# 60                                          Swan Song          14.99      USD
# 61                            Bluey: Let&#x27;s Play!           0.00      USD
# 62  Xbox Wireless Controller – Sky Cipher Special ...          69.99      USD
# 63  HP DeskJet 2855e Wireless All-in-One Color Ink...          59.99      USD
#
# ...

# %%
df['Product_price'] = df['Product_price'].apply(lambda x : round(x))
# Out:
# C:\Users\KIRTHIKA K S\AppData\Local\Temp\ipykernel_18552\3901059430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Product_price'] = df['Product_price'].apply(lambda x : round(x))

# %%
df
# Out:
#                                         Product_title  Product_price Currency  \
# 0   Moto G Play 2023 3-Day Battery Unlocked Made f...            100      USD
# 1   SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...            150      USD
# 2   Total by Verizon | Samsung Galaxy A03s | Locke...             50      USD
# 3   Google Pixel 7a - Unlocked Android Cell Phone ...            335      USD
# 4   SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...            200      USD
# ..                                                ...            ...      ...
# 59  Greatish Hits: I Followed My Dreams and My Dre...             35      USD
# 60                                          Swan Song             15      USD
# 61                            Bluey: Let&#x27;s Play!              0      USD
# 62  Xbox Wireless Controller – Sky Cipher Special ...             70      USD
# 63  HP DeskJet 2855e Wireless All-in-One Color Ink...             60      USD
#
# ...

# %%
df.to_excel("Cleaned_data.xlsx")
