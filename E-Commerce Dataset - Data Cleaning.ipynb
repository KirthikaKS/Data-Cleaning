# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\KIRTHIKA K S\\Downloads\\FashionDataset.csv\\FashionDataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30758 non-null  int64
#  1   BrandName   30758 non-null  object
#  2   Deatils     30758 non-null  object
#  3   Sizes       30758 non-null  object
#  4   MRP         30758 non-null  object
#  5   SellPrice   30758 non-null  object
#  6   Discount    30758 non-null  object
#  7   Category    30758 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.9+ MB

# %%
df.shape
# Out:
# (30758, 8)

# %%
#DELETING REDUNDANT COLUMNS
df.drop(columns = "Unnamed: 0", inplace = True)

# %%
df.head(2)
# Out:
#   BrandName                                            Deatils  \
# 0      life  solid cotton blend collar neck womens a-line d...
# 1      only  polyester peter pan collar womens blouson dres...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#RENAMING THE COLUMNS
df.rename(columns = {"Deatils" : "Details"}, inplace = True)

# %%
df.head(1)
# Out:
#   BrandName                                            Details  \
# 0      life  solid cotton blend collar neck womens a-line d...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women

# %%
#DRPPING DUPLICATES
df.duplicated().value_counts()
# Out:
# False    27931
# True      2827
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.duplicated().value_counts().plot(kind = "bar")
plt.title("Duplicated rows")
plt.xlabel("Duplicate or not")
plt.ylabel("Amount of rows")
plt.show()

# %%
df.duplicated().value_counts().plot(kind = "pie")
plt.title("Duplicated rows")
plt.ylabel("")
plt.legend()
plt.show()

# %%
df.duplicated().sum()
# Out:
# 2827

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(2)
# Out:
#   BrandName                                            Details  \
# 0      life  solid cotton blend collar neck womens a-line d...
# 1      only  polyester peter pan collar womens blouson dres...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women

# %%
#REMOVE na VALUES
df.isna().sum()
# Out:
# BrandName    0
# Details      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
#TRANSFORMATIONS
df["BrandName"] = df["BrandName"].apply(lambda x : x.capitalize())

# %%
df.head()
# Out:
#      BrandName                                            Details  \
# 0         Life  solid cotton blend collar neck womens a-line d...
# 1         Only  polyester peter pan collar womens blouson dres...
# 2      Fratini  solid polyester blend wide neck womens regular...
# 3  Zink london  stripes polyester sweetheart neck womens dress...
# 4         Life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %%
df["Details"] = df["Details"].apply(lambda x : x.capitalize())

# %%
df.tail(2)
# Out:
#       BrandName                                            Details Sizes  MRP  \
# 30756   Estelle  Womens gold plated double line fancy white and...   Nan  Nan
# 30757   Estelle  Womens gold plated bridge designer mangalsutra...   Nan  Nan
#
#       SellPrice Discount         Category
# 30756      2799      Nan  Jewellery-Women
# 30757      1899      Nan  Jewellery-Women

# %%
df["Sizes"][27929]
# Out:
# 'Nan'

# %%
type(df["Sizes"][27929])
# Out:
# str

# %%
df["Sizes"] = df["Sizes"].replace("Nan", "NA VALUED")

# %%
df.tail(2)
# Out:
#       BrandName                                            Details      Sizes  \
# 30756   Estelle  Womens gold plated double line fancy white and...  NA VALUED
# 30757   Estelle  Womens gold plated bridge designer mangalsutra...  NA VALUED
#
#        MRP SellPrice Discount         Category
# 30756  Nan      2799      Nan  Jewellery-Women
# 30757  Nan      1899      Nan  Jewellery-Women

# %%
df[df["Sizes"] == "NA VALUED"]
# Out:
#                 BrandName                                            Details  \
# 22                    Nan                                                Nan
# 640           Get wrapped  Printed polyester regular length womens casual...
# 944           Allen solly  Printed cotton mens face mask - pack of 3 - white
# 1195          Get wrapped  Printed polyester regular length womens casual...
# 1196                 Life  Assorted cotton blend soft finishes womens soc...
# ...                   ...                                                ...
# 30752  Shaya by caratlane               The wing woman clover charm necklace
# 30753           Swarovski            Crystal stylish womens rodhium earrings
# 30755              Jewelz                 Ethnic gold plated jhumki earrings
# 30756             Estelle  Womens gold plated double line fancy white and...
# 30757             Estelle  Womens gold plated bridge designer mangalsutra...
#
#            Sizes       MRP SellPrice Discount           Category
# 22     NA VALUED       Nan       Nan      Nan  Westernwear-Women
# 640    NA VALUED       Nan       399      Nan  Westernwear-Women
# 944    NA VALUED   Rs\n599       249  58% off  Westernwear-Women
# 1195   NA VALUED       Nan       399      Nan  Westernwear-Women
# 1196   NA VALUED   Rs\n299       149  50% off  Westernwear-Women
# ...          ...       ...       ...      ...                ...
# 30752  NA VALUED       Nan      1250      Nan    Jewellery-Women
# 30753  NA VALUED       Nan      8950      Nan    Jewellery-Women
# 30755  NA VALUED  Rs\n1839       643  65% off    Jewellery-Women
# 30756  NA VALUED       Nan      2799      Nan    Jewellery-Women
# 30757  NA VALUED       Nan      1899      Nan    Jewellery-Women
#
# [5244 rows x 7 columns]

# %%
df = df[df["Sizes"] != "NA VALUED"]

# %%
df
# Out:
#             BrandName                                            Details  \
# 0                Life  Solid cotton blend collar neck womens a-line d...
# 1                Only  Polyester peter pan collar womens blouson dres...
# 2             Fratini  Solid polyester blend wide neck womens regular...
# 3         Zink london  Stripes polyester sweetheart neck womens dress...
# 4                Life  Regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26885     Swiss eagle                     Womens analogue metallic watch
# 27290  Lawman watches  Womens rose gold dial stainless steel analogue...
# 28418  Lawman watches  Womens silver dial stainless steel analogue wa...
# 28664         Miu miu                              Eau de parfum - 50 ml
# 28716         Miu miu                              Eau de parfum - 30 ml
#
#                                          Sizes        MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small   Rs\n1699       849  50% off
# 1                             Size:34,36,38,40   Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large   Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large   Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36   Rs\n1699       849  50% off
# ...                                        ...        ...       ...      ...
# 26885                          Size:Error Size  Rs\n13990      4197  70% off
# 27290                          Size:Error Size   Rs\n7499      4999  33% off
# 28418                          Size:Error Size   Rs\n5999      3999  33% off
# 28664                          Size:Error Size        Nan      6100      Nan
# 28716                          Size:Error Size        Nan      4400      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
# 28664    Fragrance-Women
# 28716    Fragrance-Women
#
# [22687 rows x 7 columns]

# %%
df["Discount"] = df["Discount"].replace("Nan", "No Discount")

# %%
df
# Out:
#             BrandName                                            Details  \
# 0                Life  Solid cotton blend collar neck womens a-line d...
# 1                Only  Polyester peter pan collar womens blouson dres...
# 2             Fratini  Solid polyester blend wide neck womens regular...
# 3         Zink london  Stripes polyester sweetheart neck womens dress...
# 4                Life  Regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26885     Swiss eagle                     Womens analogue metallic watch
# 27290  Lawman watches  Womens rose gold dial stainless steel analogue...
# 28418  Lawman watches  Womens silver dial stainless steel analogue wa...
# 28664         Miu miu                              Eau de parfum - 50 ml
# 28716         Miu miu                              Eau de parfum - 30 ml
#
#                                          Sizes        MRP SellPrice  \
# 0      Size:Large,Medium,Small,X-Large,X-Small   Rs\n1699       849
# 1                             Size:34,36,38,40   Rs\n3499      2449
# 2                  Size:Large,X-Large,XX-Large   Rs\n1199       599
# 3              Size:Large,Medium,Small,X-Large   Rs\n2299      1379
# 4                       Size:26,28,30,32,34,36   Rs\n1699       849
# ...                                        ...        ...       ...
# 26885                          Size:Error Size  Rs\n13990      4197
# 27290                          Size:Error Size   Rs\n7499      4999
# 28418                          Size:Error Size   Rs\n5999      3999
# 28664                          Size:Error Size        Nan      6100
# 28716                          Size:Error Size        Nan      4400
#
#           Discount           Category
# 0          50% off  Westernwear-Women
# 1          30% off  Westernwear-Women
# 2          50% off  Westernwear-Women
# 3          40% off  Westernwear-Women
# 4          50% off  Westernwear-Women
# ...            ...                ...
# 26885      70% off      Watches-Women
# 27290      33% off      Watches-Women
# 28418      33% off      Watches-Women
# 28664  No Discount    Fragrance-Women
# 28716  No Discount    Fragrance-Women
#
# [22687 rows x 7 columns]

# %%
df = df.reset_index().drop(columns = "index")

# %%
df
# Out:
#             BrandName                                            Details  \
# 0                Life  Solid cotton blend collar neck womens a-line d...
# 1                Only  Polyester peter pan collar womens blouson dres...
# 2             Fratini  Solid polyester blend wide neck womens regular...
# 3         Zink london  Stripes polyester sweetheart neck womens dress...
# 4                Life  Regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 22682     Swiss eagle                     Womens analogue metallic watch
# 22683  Lawman watches  Womens rose gold dial stainless steel analogue...
# 22684  Lawman watches  Womens silver dial stainless steel analogue wa...
# 22685         Miu miu                              Eau de parfum - 50 ml
# 22686         Miu miu                              Eau de parfum - 30 ml
#
#                                          Sizes        MRP SellPrice  \
# 0      Size:Large,Medium,Small,X-Large,X-Small   Rs\n1699       849
# 1                             Size:34,36,38,40   Rs\n3499      2449
# 2                  Size:Large,X-Large,XX-Large   Rs\n1199       599
# 3              Size:Large,Medium,Small,X-Large   Rs\n2299      1379
# 4                       Size:26,28,30,32,34,36   Rs\n1699       849
# ...                                        ...        ...       ...
# 22682                          Size:Error Size  Rs\n13990      4197
# 22683                          Size:Error Size   Rs\n7499      4999
# 22684                          Size:Error Size   Rs\n5999      3999
# 22685                          Size:Error Size        Nan      6100
# 22686                          Size:Error Size        Nan      4400
#
#           Discount           Category
# 0          50% off  Westernwear-Women
# 1          30% off  Westernwear-Women
# 2          50% off  Westernwear-Women
# 3          40% off  Westernwear-Women
# 4          50% off  Westernwear-Women
# ...            ...                ...
# 22682      70% off      Watches-Women
# 22683      33% off      Watches-Women
# 22684      33% off      Watches-Women
# 22685  No Discount    Fragrance-Women
# 22686  No Discount    Fragrance-Women
#
# [22687 rows x 7 columns]

# %%
data.to_csv("Cleaned_CSV.csv", index = False)
