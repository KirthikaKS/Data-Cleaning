# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
df = pd.read_csv("C:\\Users\\KIRTHIKA K S\\Downloads\\credit_customers.csv")

# %%
df.head()
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0       6.0  critical/other existing credit
# 1        0<=X<200      48.0                   existing paid
# 2     no checking      12.0  critical/other existing credit
# 3              <0      42.0                   existing paid
# 4              <0      24.0              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv         1169.0  no known savings        >=7
# 1             radio/tv         5951.0              <100     1<=X<4
# 2            education         2096.0              <100     4<=X<7
# 3  furniture/equipment         7882.0              <100     4<=X<7
# 4              new car         4870.0              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  ...  \
# 0                     4.0         male single          none  ...
# 1                     2.0  female div/dep/mar          none  ...
# ...

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
df.head(2)
# Out:
#   checking_status  duration                  credit_history   purpose  \
# 0              <0       6.0  critical/other existing credit  radio/tv
# 1        0<=X<200      48.0                   existing paid  radio/tv
#
#    credit_amount    savings_status employment  installment_commitment  \
# 0         1169.0  no known savings        >=7                     4.0
# 1         5951.0              <100     1<=X<4                     2.0
#
#       personal_status other_parties  ...  property_magnitude   age  \
# 0         male single          none  ...         real estate  67.0
# 1  female div/dep/mar          none  ...         real estate  22.0
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own              2.0  skilled            1.0
# 1                 none     own              1.0  skilled            1.0
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
# ...

# %%
#DELETE REDUNDANT OR UNWANTED COLUMNS
df.drop(columns = ['checking_status', 'duration', 'credit_history', 'purpose',
      'employment','installment_commitment', 'personal_status', 'other_parties',
       'residence_since', 'property_magnitude','other_payment_plans','num_dependents'],inplace = True)

# %%
df
# Out:
#      credit_amount    savings_status   age   housing  existing_credits  \
# 0           1169.0  no known savings  67.0       own               2.0
# 1           5951.0              <100  22.0       own               1.0
# 2           2096.0              <100  49.0       own               1.0
# 3           7882.0              <100  45.0  for free               1.0
# 4           4870.0              <100  53.0  for free               2.0
# ..             ...               ...   ...       ...               ...
# 995         1736.0              <100  31.0       own               1.0
# 996         3857.0              <100  40.0       own               1.0
# 997          804.0              <100  38.0       own               1.0
# 998         1845.0              <100  23.0  for free               1.0
# 999         4576.0        100<=X<500  27.0       own               1.0
#
#                            job own_telephone foreign_worker class
# ...

# %%
df.drop(columns = 'savings_status',inplace = True)

# %%
df
# Out:
#      credit_amount   age   housing  existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            job own_telephone foreign_worker class
# 0                      skilled           yes            yes  good
# 1                      skilled          none            yes   bad
# 2           unskilled resident          none            yes  good
# ...

# %%
#RENAMING THE COLUMNS
df_new_column_names = []

for i in df.columns:
    df_new_column_names.append(i.capitalize())

# %%
df.columns = df_new_column_names

# %%
df
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            Job Own_telephone Foreign_worker Class
# 0                      skilled           yes            yes  good
# 1                      skilled          none            yes   bad
# 2           unskilled resident          none            yes  good
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Credit_amount       0
# Age                 0
# Housing             0
# Existing_credits    0
# Job                 0
# Own_telephone       0
# Foreign_worker      0
# Class               0
# dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
df.dropna(inplace = True)

# %%
df["Class"].unique()
# Out:
# array(['good', 'bad'], dtype=object)

# %%
df["Class"].apply(lambda x:1 if x == "good" else 0)
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Class, Length: 1000, dtype: int64

# %%
df["Class"] = df["Class"].apply(lambda x:1 if x == "good" else 0)

# %%
df
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            Job Own_telephone Foreign_worker  Class  Columns
# 0                      skilled           yes            yes      1        1
# 1                      skilled          none            yes      0        0
# 2           unskilled resident          none            yes      1        1
# ...

# %%
df.drop(columns = "Columns")
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            Job Own_telephone Foreign_worker  Class
# 0                      skilled           yes            yes      1
# 1                      skilled          none            yes      0
# 2           unskilled resident          none            yes      1
# ...

# %%
type(df["Existing_credits"][0])
# Out:
# numpy.float64

# %%
df["Existing_credits"].unique()
# Out:
# array([2., 1., 3., 4.])

# %%
df["Existing_credits"] = df["Existing_credits"].astype(int)

# %%
df
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own                 2
# 1           5951.0  22.0       own                 1
# 2           2096.0  49.0       own                 1
# 3           7882.0  45.0  for free                 1
# 4           4870.0  53.0  for free                 2
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own                 1
# 996         3857.0  40.0       own                 1
# 997          804.0  38.0       own                 1
# 998         1845.0  23.0  for free                 1
# 999         4576.0  27.0       own                 1
#
#                            Job Own_telephone Foreign_worker  Class  Columns
# 0                      skilled           yes            yes      1        1
# 1                      skilled          none            yes      0        0
# 2           unskilled resident          none            yes      1        1
# ...

# %%
df.to_csv("Cleaned_Credit_data.csv", index = False)
